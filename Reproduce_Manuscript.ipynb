# %% [markdown]
# # Reproduce the manuscript pipeline
#
# This notebook executes the reconstructed computational pipeline described in the manuscript.
# Place the authorized dataset at `data/breast_cancer.csv` before running the clinical analysis.

# %%
# Uncomment when running in a clean Colab environment
# !pip install -r requirements.txt

# %%
from src.pipeline import run_pipeline
results = run_pipeline('data/breast_cancer.csv', 'outputs')
